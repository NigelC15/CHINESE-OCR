# %%
import model
# Out:
# C:\Users\ASNPIJG\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\ASNPIJG\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\ASNPIJG\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
from glob import glob
from IPython.display import Image as display
import numpy as np
from PIL import Image
import time
import pandas as pd
import post_process

# %%
# result, img = post_process.get_ocr_result(model, './img_for_demo/consult only printed.TIF')
# Image.fromarray(img)
# post_process.get_basic_info_df(result)
# post_process.ocr_result_to_df(result)
# post_process.classify_text(result)

# %%
# result

# %%
paths = glob('./img_for_demo/*.*')
for path in paths:
    print('===================image separate line========================\n')
    print('------------------------------image path---------------------')
    print(path)
    result, img = post_process.get_ocr_result(model, path=path)
    Image.fromarray(img)
    print('------------------------------image type---------------------')
    post_process.classify_text(result)
    print('------------------------------basic info---------------------')
    post_process.get_basic_info_df(result)
    print('------------------------------data frame---------------------')
    post_process.ocr_result_to_df(result)
    print('\n\n\n')
# Out:
# ===================image separate line========================
#
# ------------------------------image path---------------------
# ./img_for_demo\consult + med printed (2).TIF
# It takes time:20.174740314483643s
# <PIL.Image.Image image mode=RGB size=1200x900 at 0x26C75370A90>
# ------------------------------image type---------------------
# [('medicalreport', 0)]
# ------------------------------basic info---------------------
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\ASNPIJG\AppData\Local\Temp\jieba.cache
# Loading model cost 1.853 seconds.
# Prefix dict has been built successfully.
# {'hospital': 'EASEHEALTHMEDICALCENTREO/BWISEASEENTERPRISESLIMITED',
#  'doctor': 'WAISHIUFAI',
#  'name': 'LOKRYSTENYINLAM-彦霖',
#  'sex': None,
#  'date': '10September,2017',
#  'diagnosis': 'UPPERRESPIRATORYTRACTINFECTION',
#  'total': '.370.00',
#  'paid': '370.00'}
# ------------------------------data frame---------------------
# ...
